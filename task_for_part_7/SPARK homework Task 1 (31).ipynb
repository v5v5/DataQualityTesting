# %% [markdown]
# # PRECONDITIONS

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()
spark.sparkContext.getConf().getAll()
# Out:
# [('spark.driver.extraJavaOptions',
#   '"-Dio.netty.tryReflectionSetAccessible=true"'),
#  ('spark.app.id', 'local-1616503488489'),
#  ('spark.executor.id', 'driver'),
#  ('spark.driver.port', '40761'),
#  ('spark.driver.host', 'fa6ae6620e7d'),
#  ('spark.app.name', 'pyspark-shell'),
#  ('spark.executor.extraJavaOptions',
#   '"-Dio.netty.tryReflectionSetAccessible=true"'),
#  ('spark.rdd.compress', 'True'),
#  ('spark.serializer.objectStreamReset', '100'),
#  ('spark.master', 'local[*]'),
#  ('spark.submit.pyFiles', ''),
#  ('spark.submit.deployMode', 'client'),
#  ('spark.ui.showConsoleProgress', 'true'),
#  ('spark.app.startTime', '1616503486876')]

# %%
df_csv = spark.read.option('sep',',').option("header",True).option("inferSchema", True).csv("./flights.csv")
# df_csv = spark.read.option('sep',',').option("header",True).csv("./flights.csv")

# %%
df = df_csv

# %%
# df.printSchema()

# %%
# df.show(1)

# %% [markdown]
# # 1.2. Implement each query using Spark Dataframe API

# %%
from pyspark.sql.functions import concat_ws
import pyspark.sql.functions as F
from pyspark.sql.window import Window

dfr1 = df\
.select(
    concat_ws(
        "-",
        F.format_string('%04d', df['YEAR']),
        F.format_string('%02d', df['MONTH']),
        F.format_string('%02d', df['DAY'])
    )
    .alias('departure_date'),
#     df['SCHEDULED_DEPARTURE'],
#     df['DEPARTURE_TIME'],
    F.when(F.col("DEPARTURE_TIME").isNull(), '00:00:00')
    .otherwise(
        concat_ws(
            ":",
            F.format_string('%02d', F.floor(df['DEPARTURE_TIME']/100)), 
            F.format_string('%02d', df['DEPARTURE_TIME']%100), 
            F.lit("00")
        )
    )
    .alias('departure_time'),
    df['AIRLINE'].alias('airline'),
    df['FLIGHT_NUMBER'].alias('flight_number'),
)
# .where(df['SCHEDULED_DEPARTURE'].between(59,101) )
# .orderBy(['departure_date', 'departure_time_f'])

# dfr.show(100)

dfr2 = dfr1\
.withColumn(
    'daily_flight_serial_number',
    F.row_number().over(
        Window.partitionBy('departure_date').orderBy('departure_time')
    )
)\
.withColumn(
    'airline_daily_flights_count', 
    F.count('*').over(
        Window.partitionBy('departure_date', 'airline')
    )
)\
.withColumn(
    'time_since_previous_departure',
    F.floor(
        (
            F.unix_timestamp('departure_time', 'HH:mm:ss') - F.lag(F.unix_timestamp('departure_time', 'HH:mm:ss'))
            .over(
                Window.partitionBy('departure_date', 'airline').orderBy('departure_time')
            )
        ) / 60
    )
)\
.orderBy(['departure_date', 'daily_flight_serial_number'])

dfr2.show(10)

# %%
df_parquet = spark.read.parquet('golden_dataset/query1')

# %%
df = df_parquet
# df.printSchema()
df.show(10)
# Out:
# +--------------+--------------+-------+-------------+--------------------------+---------------------------+-----------------------------+
# |departure_date|departure_time|airline|flight_number|daily_flight_serial_number|airline_daily_flights_count|time_since_previous_departure|
# +--------------+--------------+-------+-------------+--------------------------+---------------------------+-----------------------------+
# |    2015-01-01|      00:00:00|     AA|         1285|                        59|                       1473|                            0|
# |    2015-01-01|      00:00:00|     MQ|         3263|                       295|                        929|                            0|
# |    2015-01-01|      00:00:00|     OO|         5445|                        33|                       1487|                            0|
# |    2015-01-01|      06:05:00|     UA|         1224|                       840|                       1285|                            2|
# |    2015-01-01|      06:12:00|     UA|          374|                       896|                       1285|                            2|
# |    2015-01-01|      07:26:00|     UA|          656|                      1595|                       1285|                            2|
# |    2015-01-01|      07:35:00|     B6|         1033|                      1696|                        757|                            0|
# |    2015-01-01|      07:42:00|     DL|         1430|                      1770|                       1559|                            2|
# |    2015-01-01|      07:54:00|     B6|         1347|                      1890|                        757|                            1|
# |    2015-01-01|      08:06:00|     OO|         5178|                      2080|                       1487|                            1|
# +--------------+--------------+-------+-------------+--------------------------+---------------------------+-----------------------------+
# only showing top 10 rows

# %% [markdown]
# # 1.2.2. Compare query results with golden dataset (to be provided) using Spark Dataframe API. It's allowed to use EXCEPT clause

# %%
diff = dfr2.subtract(df_parquet)

# %%
# diff.show()
diff.count()
# Out:
# 10313

# %% [markdown]
# # 1.2.3. Save difference between datasets (if any) to both Excel and Parquet files

# %%
diff.toPandas().to_csv('diff.csv')
diff.write.parquet("diff.parquet")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-543-86ee447a43a4> in <module>
#       1 diff.toPandas().to_csv('diff.csv')
# ----> 2 diff.write.parquet("diff.parquet")
#
# /usr/local/spark/python/pyspark/sql/readwriter.py in parquet(self, path, mode, partitionBy, compression)
#    1247             self.partitionBy(partitionBy)
#    1248         self._set_opts(compression=compression)
# -> 1249         self._jwrite.parquet(path)
#    1250
#    1251     def text(self, path, compression=None, lineSep=None):
#
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# AnalysisException: path file:/home/jovyan/diff.parquet already exists.

# %%
import pandas as pd 
import numpy as np 

# Reading the csv file 
df_csv = pd.read_csv('diff.csv') 
  
# saving xlsx file 
xlsx_writer = pd.ExcelWriter('diff.xlsx') 
df_csv.to_excel(GFG, index = False) 
  
xlsx_writer.save()

# %% [markdown]
# # 1.2.4. Create test report consisting of:
# 	- Spark Dataframe API query
# 	- datasets comparison query
# 	- difference between datasets' rows in Excel format
# 	- difference between datasets' rows in Parquet format

# %%
diff.describe().show()

# %%
diff.summary().show()

# %% [markdown]
# # 1.1. Implement each query in Spark SQL (see org.apache.spark.sql.SparkSession#sql)

# %%
flights_csv = spark.read\
.option('multiline', True)\
.option("mode", "FAILFAST")\
.option("header", True)\
.option("inferSchema", "true")\
.csv('flights.csv')

# %%
# flights_csv.show()
flights_csv.createOrReplaceTempView('flights_csv')

# %%
spark.sql('SELECT YEAR, MONTH, AIRLINE, ORIGIN_AIRPORT, DESTINATION_AIRPORT, DEPARTURE_DELAY, ARRIVAL_DELAY, CANCELLED, DIVERTED FROM flights_csv').show(5)
# Out:
# +----+-----+-------+--------------+-------------------+---------------+-------------+---------+--------+
# |YEAR|MONTH|AIRLINE|ORIGIN_AIRPORT|DESTINATION_AIRPORT|DEPARTURE_DELAY|ARRIVAL_DELAY|CANCELLED|DIVERTED|
# +----+-----+-------+--------------+-------------------+---------------+-------------+---------+--------+
# |2015|    1|     AS|           ANC|                SEA|            -11|          -22|        0|       0|
# |2015|    1|     AA|           LAX|                PBI|             -8|           -9|        0|       0|
# |2015|    1|     US|           SFO|                CLT|             -2|            5|        0|       0|
# |2015|    1|     AA|           LAX|                MIA|             -5|           -9|        0|       0|
# |2015|    1|     AS|           SEA|                ANC|             -1|          -21|        0|       0|
# +----+-----+-------+--------------+-------------------+---------------+-------------+---------+--------+
# only showing top 5 rows

# %%
df = spark.sql('''
SELECT 
    count(AIRLINE)
FROM
    flights_csv
WHERE 
    YEAR=2015 and MONTH=1 and AIRLINE="AA" and ORIGIN_AIRPORT = "LAX" and (
        ((DEPARTURE_DELAY > 0 AND ARRIVAL_DELAY > 0) OR (CANCELLED != 0)) 
    )
group by AIRLINE
''')

df.show(5)

# %%
df = spark.sql('''
SELECT 
    count(*)
FROM
    flights_csv
WHERE 
    YEAR=2015 and MONTH=1 and AIRLINE="AA" and DESTINATION_AIRPORT = "MIA" and (
        ((DEPARTURE_DELAY <= 0 AND ARRIVAL_DELAY > 0) OR (DIVERTED != 0))
    )
group by AIRLINE
''')

df.show(5)

# %%
airlines_csv = spark.read\
.option('multiline', True)\
.option("mode", "FAILFAST")\
.option("header", True)\
.option("inferSchema", "true")\
.csv('airlines.csv')

# %%
airlines_csv.show()
# Out:
# +---------+--------------------+
# |IATA_CODE|             AIRLINE|
# +---------+--------------------+
# |       UA|United Air Lines ...|
# |       AA|American Airlines...|
# |       US|     US Airways Inc.|
# |       F9|Frontier Airlines...|
# |       B6|     JetBlue Airways|
# |       OO|Skywest Airlines ...|
# |       AS|Alaska Airlines Inc.|
# |       NK|    Spirit Air Lines|
# |       WN|Southwest Airline...|
# |       DL|Delta Air Lines Inc.|
# |       EV|Atlantic Southeas...|
# |       HA|Hawaiian Airlines...|
# |       MQ|American Eagle Ai...|
# |       VX|      Virgin America|
# +---------+--------------------+

# %%
airlines_csv.createOrReplaceTempView('airlines_iata')

# %%
spark.sql('SELECT * FROM airlines_iata').show()
# Out:
# +---------+--------------------+
# |IATA_CODE|             AIRLINE|
# +---------+--------------------+
# |       UA|United Air Lines ...|
# |       AA|American Airlines...|
# |       US|     US Airways Inc.|
# |       F9|Frontier Airlines...|
# |       B6|     JetBlue Airways|
# |       OO|Skywest Airlines ...|
# |       AS|Alaska Airlines Inc.|
# |       NK|    Spirit Air Lines|
# |       WN|Southwest Airline...|
# |       DL|Delta Air Lines Inc.|
# |       EV|Atlantic Southeas...|
# |       HA|Hawaiian Airlines...|
# |       MQ|American Eagle Ai...|
# |       VX|      Virgin America|
# +---------+--------------------+

# %%
df_json = spark.read.option('multiline', True).option("mode", "FAILFAST").option("inferSchema", "true").json('airlines.json')

# %%
import pyspark.sql.functions as F

df = df_json.select(
    F.col('Airport.Code').alias('Airport.Code'),
    F.col('Airport.Name').alias('Airport.Name'),

    F.col('Time.Label').alias('Time.Label'),
    F.col('Time.Month').alias('Time.Month'),
    F.col('Time.Month Name').alias('Time.Month Name'),
    F.col('Time.Year').alias('Time.Year'),
    
    F.col('Statistics.# of Delays.Carrier').alias('Statistics.# of Delays.Carrier'),
    F.col('Statistics.# of Delays.Late Aircraft').alias('Statistics.# of Delays.Late Aircraft'),
    F.col('Statistics.# of Delays.National Aviation System').alias('Statistics.# of Delays.National Aviation System'),
    F.col('Statistics.# of Delays.Security').alias('Statistics.# of Delays.Security'),
    F.col('Statistics.# of Delays.Weather').alias('Statistics.# of Delays.Weather'),

    F.col('Statistics.Carriers.Names').alias('Statistics.Carriers.Names'),
    F.col('Statistics.Carriers.Total').alias('Statistics.Carriers.Total'),

    F.col('Statistics.Flights.Cancelled').alias('Statistics.Flights.Cancelled'),
    F.col('Statistics.Flights.Delayed').alias('Statistics.Flights.Delayed'),
    F.col('Statistics.Flights.Diverted').alias('Statistics.Flights.Diverted'),
    F.col('Statistics.Flights.On Time').alias('Statistics.Flights.On Time'),
    F.col('Statistics.Flights.Total').alias('Statistics.Flights.Total'),
    
    F.col('Statistics.Minutes Delayed.Carrier').alias('Statistics.Minutes Delayed.Carrier'),
    F.col('Statistics.Minutes Delayed.Late Aircraft').alias('Statistics.Minutes Delayed.Late Aircraft'),
    F.col('Statistics.Minutes Delayed.National Aviation System').alias('Statistics.Minutes Delayed.National Aviation System'),
    F.col('Statistics.Minutes Delayed.Security').alias('Statistics.Minutes Delayed.Security'),
    F.col('Statistics.Minutes Delayed.Total').alias('Statistics.Minutes Delayed.Total'),
    F.col('Statistics.Minutes Delayed.Weather').alias('Statistics.Minutes Delayed.Weather'),
)

# %%
df.show(1)

# %%
df.createOrReplaceTempView('airlines_json')

# %%
df_json = spark.sql('SELECT * FROM airlines_json')
df_json.show(2)
# Out:
# +------------+--------------------+----------+----------+---------------+---------+------------------------------+------------------------------------+-----------------------------------------------+-------------------------------+------------------------------+-------------------------+-------------------------+----------------------------+--------------------------+---------------------------+--------------------------+------------------------+----------------------------------+----------------------------------------+---------------------------------------------------+-----------------------------------+--------------------------------+----------------------------------+
# |Airport.Code|        Airport.Name|Time.Label|Time.Month|Time.Month Name|Time.Year|Statistics.# of Delays.Carrier|Statistics.# of Delays.Late Aircraft|Statistics.# of Delays.National Aviation System|Statistics.# of Delays.Security|Statistics.# of Delays.Weather|Statistics.Carriers.Names|Statistics.Carriers.Total|Statistics.Flights.Cancelled|Statistics.Flights.Delayed|Statistics.Flights.Diverted|Statistics.Flights.On Time|Statistics.Flights.Total|Statistics.Minutes Delayed.Carrier|Statistics.Minutes Delayed.Late Aircraft|Statistics.Minutes Delayed.National Aviation System|Statistics.Minutes Delayed.Security|Statistics.Minutes Delayed.Total|Statistics.Minutes Delayed.Weather|
# +------------+--------------------+----------+----------+---------------+---------+------------------------------+------------------------------------+-----------------------------------------------+-------------------------------+------------------------------+-------------------------+-------------------------+----------------------------+--------------------------+---------------------------+--------------------------+------------------------+----------------------------------+----------------------------------------+---------------------------------------------------+-----------------------------------+--------------------------------+----------------------------------+
# |         ATL|Atlanta, GA: Hart...|   2003/06|         6|           June|     2003|                          1009|                                1275|                                           3217|                             17|                           328|     American Airlines...|                       11|                         216|                      5843|                         27|                     23974|                   30060|                             61606|                                   68335|                                             118831|                                518|                          268764|                             19474|
# |         BOS|Boston, MA: Logan...|   2003/06|         6|           June|     2003|                           374|                                 495|                                            685|                              3|                            66|     American Airlines...|                       14|                         138|                      1623|                          3|                      7875|                    9639|                             20319|                                   28189|                                              24400|                                 99|                           77167|                              4160|
# +------------+--------------------+----------+----------+---------------+---------+------------------------------+------------------------------------+-----------------------------------------------+-------------------------------+------------------------------+-------------------------+-------------------------+----------------------------+--------------------------+---------------------------+--------------------------+------------------------+----------------------------------+----------------------------------------+---------------------------------------------------+-----------------------------------+--------------------------------+----------------------------------+
# only showing top 2 rows

# %%
df_res = spark.sql('''
SELECT 
    year_month,
    airport_code,
    number_of_delays_for_airport,
    airline_name,
    ifnull(airlines_iata.IATA_CODE, "N/A") as airline_iata_code,
    CASE 
        WHEN airlines_iata.IATA_CODE is null 
        THEN null 
        ELSE (
            SELECT 
                count(*)
            FROM
                flights_csv
            WHERE 
                year_month = CONCAT(`YEAR`, "-", format_number(`MONTH`, "00")) and 
                    AIRLINE=airlines_iata.IATA_CODE and 
                    ORIGIN_AIRPORT = airport_code and (
                        ((DEPARTURE_DELAY > 0 AND ARRIVAL_DELAY > 0) OR (CANCELLED != 0)) 
                    )
            GROUP BY AIRLINE 
            ) + (
            SELECT 
                count(*)
            FROM
                flights_csv
            WHERE 
                year_month = CONCAT(`YEAR`, "-", format_number(`MONTH`, "00")) and
                AIRLINE=airlines_iata.IATA_CODE and
                DESTINATION_AIRPORT = airport_code and (
                    ((DEPARTURE_DELAY <= 0 AND ARRIVAL_DELAY > 0) OR (DIVERTED != 0))
                )
            GROUP BY AIRLINE
            )
    END AS number_of_delays_for_airline_in_airport
FROM (

    SELECT 
        CONCAT(`Time.Year`, "-", format_number(`Time.Month`, "00")) as year_month,
        `Airport.Code` as airport_code,
        (`Statistics.Flights.Cancelled` + `Statistics.Flights.Delayed` + `Statistics.Flights.Diverted`) as number_of_delays_for_airport,
        airline_name
    FROM airlines_json 
        LATERAL VIEW EXPLODE(split(`Statistics.Carriers.Names`, ',')) AS airline_name
    WHERE `Time.Year` = "2015"

)
LEFT JOIN airlines_iata ON airlines_iata.AIRLINE=airline_name
''')
df_res.show(1000)
# df1.count()
# Out:
# +----------+------------+----------------------------+--------------------+-----------------+---------------------------------------+
# |year_month|airport_code|number_of_delays_for_airport|        airline_name|airline_iata_code|number_of_delays_for_airline_in_airport|
# +----------+------------+----------------------------+--------------------+-----------------+---------------------------------------+
# |   2015-01|         ATL|                        4651|American Airlines...|               AA|                                    146|
# |   2015-02|         MDW|                        1572|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-02|         MDW|                        1572|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-02|         DCA|                        1929|      Virgin America|               VX|                                     54|
# |   2015-03|         DEN|                        3354|United Air Lines ...|               UA|                                   1615|
# |   2015-03|         PHL|                        1557|     US Airways Inc.|               US|                                   1648|
# |   2015-04|         ATL|                        4545|American Airlines...|               AA|                                    116|
# |   2015-04|         BOS|                        1973|United Air Lines ...|               UA|                                    328|
# |   2015-04|         BWI|                        1113|Southwest Airline...|               WN|                                   2252|
# |   2015-06|         DTW|                        2423|Frontier Airlines...|               F9|                                     23|
# |   2015-06|         DCA|                        1765|United Air Lines ...|               UA|                                    248|
# |   2015-06|         ATL|                        6526|Southwest Airline...|               WN|                                   1829|
# |   2015-07|         SAN|                        1646|American Airlines...|               AA|                                    234|
# |   2015-08|         DEN|                        3481|Frontier Airlines...|               F9|                                    721|
# |   2015-09|         SAN|                         760|      Virgin America|               VX|                                     48|
# |   2015-11|         PDX|                         576|Alaska Airlines Inc.|               AS|                                    298|
# |   2015-11|         MSP|                        1559|Delta Air Lines Inc.|               DL|                                   1274|
# |   2015-12|         PHX|                        2836|    Spirit Air Lines|               NK|                                     83|
# |   2015-01|         LGA|                        3514|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-01|         LGA|                        3514|           Envoy Air|              N/A|                                   null|
# |   2015-01|         LGA|                        3514|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-01|         BWI|                        1441|Alaska Airlines Inc.|               AS|                                     11|
# |   2015-01|         SAN|                        1079|    Spirit Air Lines|               NK|                                     38|
# |   2015-03|         SEA|                        1355|Hawaiian Airlines...|               HA|                                     13|
# |   2015-03|         LAS|                        2287|United Air Lines ...|               UA|                                    291|
# |   2015-04|         SLC|                        1120|Frontier Airlines...|               F9|                                     43|
# |   2015-05|         LGA|                        2344|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-05|         LGA|                        2344|           Envoy Air|              N/A|                                   null|
# |   2015-05|         LGA|                        2344|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-06|         PHX|                        2852|American Airlines...|               AA|                                     92|
# |   2015-06|         DCA|                        1765|     US Airways Inc.|               US|                                    666|
# |   2015-07|         EWR|                        2918|American Airlines...|               AA|                                    280|
# |   2015-08|         EWR|                        2169|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-08|         EWR|                        2169|           Envoy Air|              N/A|                                   null|
# |   2015-08|         LGA|                        2164|     JetBlue Airways|               B6|                                    257|
# |   2015-10|         LAS|                        1711|Delta Air Lines Inc.|               DL|                                      0|
# |   2015-11|         DTW|                        1181|Delta Air Lines Inc.|               DL|                                   1018|
# |   2015-11|         DCA|                         980|Frontier Airlines...|               F9|                                     26|
# |   2015-11|         BWI|                        1089|    Spirit Air Lines|               NK|                                    151|
# |   2015-11|         MCO|                        1379|United Air Lines ...|               UA|                                    253|
# |   2015-12|         ATL|                        5899|Alaska Airlines Inc.|               AS|                                     28|
# |   2015-12|         BWI|                        1537|     JetBlue Airways|               B6|                                     55|
# |   2015-01|         BOS|                        2638|American Airlines...|               AA|                                    340|
# |   2015-01|         PHL|                        1635|American Airlines...|               AA|                                    118|
# |   2015-06|         LAX|                        4910|Frontier Airlines...|               F9|                                     54|
# |   2015-06|         SAN|                        1576|     US Airways Inc.|               US|                                     95|
# |   2015-06|         FLL|                        1665|      Virgin America|               VX|                                     15|
# |   2015-07|         BWI|                        2142|Delta Air Lines Inc.|               DL|                                    160|
# |   2015-08|         LAX|                        5004|Hawaiian Airlines...|               HA|                                     49|
# |   2015-09|         CLT|                        1239|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-09|         CLT|                        1239|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-09|         DEN|                        1853|American Airlines...|               AA|                                    242|
# |   2015-10|         LAX|                        2353|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-10|         PHL|                         929|     JetBlue Airways|               B6|                                      0|
# |   2015-10|         BWI|                         919|    Spirit Air Lines|               NK|                                      0|
# |   2015-11|         LAX|                        3080|American Airlines...|               AA|                                    964|
# |   2015-01|         SAN|                        1079|American Airlines...|               AA|                                    112|
# |   2015-01|         DEN|                        4211|     US Airways Inc.|               US|                                    158|
# |   2015-02|         SFO|                        3335|Alaska Airlines Inc.|               AS|                                    166|
# |   2015-03|         MIA|                        1531|           Envoy Air|              N/A|                                   null|
# |   2015-03|         MIA|                        1531|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-03|         IAH|                        2907|Frontier Airlines...|               F9|                                     66|
# |   2015-03|         MCO|                        2557|      Virgin America|               VX|                                     14|
# |   2015-05|         JFK|                        1656|American Airlines...|               AA|                                    371|
# |   2015-05|         JFK|                        1656|     JetBlue Airways|               B6|                                    896|
# |   2015-06|         FLL|                        1665|American Airlines...|               AA|                                     63|
# |   2015-06|         SAN|                        1576|      Virgin America|               VX|                                     53|
# |   2015-08|         LAS|                        2464|      Virgin America|               VX|                                    157|
# |   2015-09|         IAD|                         405|     JetBlue Airways|               B6|                                     57|
# |   2015-10|         MIA|                         740|           Envoy Air|              N/A|                                   null|
# |   2015-10|         MIA|                         740|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-10|         MSP|                        1189|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-10|         MSP|                        1189|           Envoy Air|              N/A|                                   null|
# |   2015-10|         MSP|                        1189|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-12|         PDX|                        1005|American Airlines...|               AA|                                    116|
# |   2015-01|         LAX|                        3305|      Virgin America|               VX|                                    341|
# |   2015-01|         SEA|                        1653|Southwest Airline...|               WN|                                    315|
# |   2015-02|         PHX|                        2345|Hawaiian Airlines...|               HA|                                     13|
# |   2015-03|         SFO|                        2633|Alaska Airlines Inc.|               AS|                                    146|
# |   2015-03|         PHX|                        2421|     US Airways Inc.|               US|                                   2109|
# |   2015-04|         FLL|                        1206|Delta Air Lines Inc.|               DL|                                    226|
# |   2015-04|         SAN|                        1225|Frontier Airlines...|               F9|                                     27|
# |   2015-04|         DEN|                        3252|Southwest Airline...|               WN|                                   1797|
# |   2015-05|         LAX|                        3775|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-05|         BOS|                        1974|Alaska Airlines Inc.|               AS|                                     26|
# |   2015-05|         SLC|                         957|Alaska Airlines Inc.|               AS|                                     35|
# |   2015-05|         SFO|                        3912|Delta Air Lines Inc.|               DL|                                    203|
# |   2015-07|         CLT|                        1671|American Airlines...|               AA|                                   3662|
# |   2015-08|         ORD|                        5895|American Airlines...|               AA|                                   1868|
# |   2015-08|         DEN|                        3481|Delta Air Lines Inc.|               DL|                                    252|
# |   2015-08|         IAH|                        2502|United Air Lines ...|               UA|                                   2123|
# |   2015-10|         DFW|                        3143|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-10|         DFW|                        3143|           Envoy Air|              N/A|                                   null|
# |   2015-10|         DFW|                        3143|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-12|         SEA|                        2171|      Virgin America|               VX|                                    129|
# |   2015-01|         MIA|                        1603|Frontier Airlines...|               F9|                                    159|
# |   2015-02|         PHX|                        2345|Delta Air Lines Inc.|               DL|                                    132|
# |   2015-03|         PHL|                        1557|Alaska Airlines Inc.|               AS|                                     10|
# |   2015-05|         SLC|                         957|American Airlines...|               AA|                                     79|
# |   2015-05|         LAX|                        3775|      Virgin America|               VX|                                    476|
# |   2015-06|         IAD|                         979|Frontier Airlines...|               F9|                                     81|
# |   2015-06|         PHL|                        1726|     US Airways Inc.|               US|                                   1507|
# |   2015-09|         DCA|                        1066|     JetBlue Airways|               B6|                                    243|
# |   2015-09|         ATL|                        3243|Delta Air Lines Inc.|               DL|                                   4282|
# |   2015-09|         BWI|                        1260|    Spirit Air Lines|               NK|                                    145|
# |   2015-10|         BOS|                        1538|Southwest Airline...|               WN|                                      0|
# |   2015-11|         DCA|                         980|United Air Lines ...|               UA|                                     90|
# |   2015-11|         PDX|                         576|United Air Lines ...|               UA|                                    100|
# |   2015-11|         EWR|                        2116|      Virgin America|               VX|                                     42|
# |   2015-12|         ORD|                        5219|     JetBlue Airways|               B6|                                     88|
# |   2015-02|         LAX|                        3766|Alaska Airlines Inc.|               AS|                                    223|
# |   2015-02|         DFW|                        6194|Frontier Airlines...|               F9|                                     56|
# |   2015-02|         ATL|                        5685|     US Airways Inc.|               US|                                    158|
# |   2015-02|         JFK|                        2665|     US Airways Inc.|               US|                                    116|
# |   2015-03|         SAN|                        1141|Delta Air Lines Inc.|               DL|                                    118|
# |   2015-03|         SFO|                        2633|Southwest Airline...|               WN|                                    466|
# |   2015-04|         FLL|                        1206|American Airlines...|               AA|                                     73|
# |   2015-06|         DTW|                        2423|     JetBlue Airways|               B6|                                     45|
# |   2015-06|         SAN|                        1576|Hawaiian Airlines...|               HA|                                     18|
# |   2015-07|         PDX|                         982|Alaska Airlines Inc.|               AS|                                    389|
# |   2015-08|         MIA|                        1521|American Airlines...|               AA|                                   2560|
# |   2015-09|         MSP|                        1370|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-09|         MSP|                        1370|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-09|         DCA|                        1066|Delta Air Lines Inc.|               DL|                                    214|
# |   2015-10|         BWI|                         919|Southwest Airline...|               WN|                                      0|
# |   2015-10|         DEN|                        2260|Southwest Airline...|               WN|                                      0|
# |   2015-12|         DFW|                        3993|     JetBlue Airways|               B6|                                     17|
# |   2015-02|         LAS|                        2243|      Virgin America|               VX|                                    149|
# |   2015-02|         ATL|                        5685|Southwest Airline...|               WN|                                   1367|
# |   2015-03|         TPA|                        1403|Alaska Airlines Inc.|               AS|                                      9|
# |   2015-04|         MIA|                        1126|           Envoy Air|              N/A|                                   null|
# |   2015-04|         MIA|                        1126|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-04|         FLL|                        1206|Alaska Airlines Inc.|               AS|                                      8|
# |   2015-04|         LAX|                        3667|     JetBlue Airways|               B6|                                    165|
# |   2015-04|         LGA|                        2187|Delta Air Lines Inc.|               DL|                                    969|
# |   2015-05|         MSP|                        1666|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-05|         MSP|                        1666|           Envoy Air|              N/A|                                   null|
# |   2015-05|         MSP|                        1666|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-05|         DEN|                        3693|Delta Air Lines Inc.|               DL|                                    204|
# |   2015-05|         EWR|                        1740|     US Airways Inc.|               US|                                     76|
# |   2015-06|         IAH|                        3985|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-06|         IAH|                        3985|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-07|         MSP|                        2151|Delta Air Lines Inc.|               DL|                                   2127|
# |   2015-07|         SEA|                        2047|Southwest Airline...|               WN|                                    644|
# |   2015-09|         SFO|                        2003|     JetBlue Airways|               B6|                                    199|
# |   2015-10|         MIA|                         740|United Air Lines ...|               UA|                                      0|
# |   2015-11|         MCO|                        1379|    Spirit Air Lines|               NK|                                    215|
# |   2015-04|         ATL|                        4545|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-04|         ATL|                        4545|           Envoy Air|              N/A|                                   null|
# |   2015-04|         ATL|                        4545|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-04|         EWR|                        1726|American Airlines...|               AA|                                     78|
# |   2015-05|         PHL|                        1272|     JetBlue Airways|               B6|                                     32|
# |   2015-05|         SLC|                         957|Frontier Airlines...|               F9|                                     46|
# |   2015-05|         PHL|                        1272|Southwest Airline...|               WN|                                    195|
# |   2015-07|         BOS|                        2445|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-07|         BOS|                        2445|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-07|         FLL|                        1519|Alaska Airlines Inc.|               AS|                                     13|
# |   2015-09|         DEN|                        1853|Delta Air Lines Inc.|               DL|                                    142|
# |   2015-10|         EWR|                        1741|American Airlines...|               AA|                                      0|
# |   2015-10|         FLL|                        1019|Alaska Airlines Inc.|               AS|                                      0|
# |   2015-10|         LGA|                        1593|Southwest Airline...|               WN|                                      0|
# |   2015-11|         SEA|                        1639|United Air Lines ...|               UA|                                    156|
# |   2015-01|         DFW|                        5876|Delta Air Lines Inc.|               DL|                                    106|
# |   2015-01|         FLL|                        1568|United Air Lines ...|               UA|                                    130|
# |   2015-02|         DFW|                        6194|Alaska Airlines Inc.|               AS|                                     22|
# |   2015-03|         CLT|                        1679|     US Airways Inc.|               US|                                   3464|
# |   2015-04|         DFW|                        5468|Frontier Airlines...|               F9|                                     65|
# |   2015-05|         DTW|                        1646|Alaska Airlines Inc.|               AS|                                     12|
# |   2015-08|         MCO|                        2578|      Virgin America|               VX|                                     14|
# |   2015-10|         DEN|                        2260|    Spirit Air Lines|               NK|                                      0|
# |   2015-10|         DTW|                        1114|United Air Lines ...|               UA|                                      0|
# |   2015-11|         FLL|                         993|    Spirit Air Lines|               NK|                                    403|
# |   2015-12|         DTW|                        1571|     JetBlue Airways|               B6|                                     27|
# |   2015-12|         MCO|                        2387|    Spirit Air Lines|               NK|                                    300|
# |   2015-12|         SAN|                        1469|      Virgin America|               VX|                                     92|
# |   2015-02|         PDX|                         579|    Spirit Air Lines|               NK|                                     11|
# |   2015-02|         LAX|                        3766|United Air Lines ...|               UA|                                    760|
# |   2015-03|         MCO|                        2557|American Airlines...|               AA|                                    316|
# |   2015-03|         DEN|                        3354|Alaska Airlines Inc.|               AS|                                     28|
# |   2015-04|         CLT|                        1453|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-04|         CLT|                        1453|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-04|         DCA|                        1101|Frontier Airlines...|               F9|                                     38|
# |   2015-04|         DCA|                        1101|     US Airways Inc.|               US|                                    637|
# |   2015-04|         DCA|                        1101|      Virgin America|               VX|                                     49|
# |   2015-05|         JFK|                        1656|Delta Air Lines Inc.|               DL|                                    606|
# |   2015-06|         SEA|                        2113|Hawaiian Airlines...|               HA|                                     22|
# |   2015-07|         LAS|                        2874|American Airlines...|               AA|                                    375|
# |   2015-08|         ATL|                        5412|American Airlines...|               AA|                                    266|
# |   2015-08|         BWI|                        1742|American Airlines...|               AA|                                    219|
# |   2015-08|         SFO|                        3331|American Airlines...|               AA|                                    335|
# |   2015-08|         MCO|                        2578|    Spirit Air Lines|               NK|                                    240|
# |   2015-08|         SLC|                        1223|United Air Lines ...|               UA|                                     35|
# |   2015-09|         SFO|                        2003|Delta Air Lines Inc.|               DL|                                    283|
# |   2015-10|         MDW|                         658|Delta Air Lines Inc.|               DL|                                      0|
# |   2015-11|         DTW|                        1181|Southwest Airline...|               WN|                                    157|
# |   2015-12|         IAD|                         474|American Airlines...|               AA|                                     73|
# |   2015-12|         MSP|                        1932|American Airlines...|               AA|                                    196|
# |   2015-01|         TPA|                        1220|Frontier Airlines...|               F9|                                    123|
# |   2015-03|         SEA|                        1355|     JetBlue Airways|               B6|                                     89|
# |   2015-05|         ATL|                        4741|United Air Lines ...|               UA|                                    185|
# |   2015-05|         SLC|                         957|     US Airways Inc.|               US|                                     41|
# |   2015-07|         PHL|                        1399|Alaska Airlines Inc.|               AS|                                      5|
# |   2015-07|         IAH|                        2559|Delta Air Lines Inc.|               DL|                                     69|
# |   2015-09|         JFK|                        1557|Alaska Airlines Inc.|               AS|                                      0|
# |   2015-10|         IAH|                        1968|American Airlines...|               AA|                                      0|
# |   2015-10|         PHX|                        1633|Alaska Airlines Inc.|               AS|                                      0|
# |   2015-10|         MIA|                         740|Frontier Airlines...|               F9|                                      0|
# |   2015-10|         FLL|                        1019|United Air Lines ...|               UA|                                      0|
# |   2015-11|         ORD|                        4952|American Airlines...|               AA|                                   1689|
# |   2015-11|         MSP|                        1559|Alaska Airlines Inc.|               AS|                                     25|
# |   2015-11|         CLT|                        1093|     JetBlue Airways|               B6|                                     52|
# |   2015-11|         FLL|                         993|Frontier Airlines...|               F9|                                      1|
# |   2015-12|         DTW|                        1571|Alaska Airlines Inc.|               AS|                                     14|
# |   2015-01|         DTW|                        1920|Delta Air Lines Inc.|               DL|                                   1197|
# |   2015-01|         LAX|                        3305|Frontier Airlines...|               F9|                                     42|
# |   2015-01|         TPA|                        1220|Southwest Airline...|               WN|                                    748|
# |   2015-02|         LAS|                        2243|     US Airways Inc.|               US|                                    141|
# |   2015-03|         SAN|                        1141|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-03|         PHL|                        1557|Frontier Airlines...|               F9|                                    118|
# |   2015-04|         SFO|                        2635|Hawaiian Airlines...|               HA|                                     22|
# |   2015-05|         PHX|                        2226|Alaska Airlines Inc.|               AS|                                    113|
# |   2015-06|         SEA|                        2113|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-08|         PHL|                        1301|Alaska Airlines Inc.|               AS|                                      5|
# |   2015-08|         SFO|                        3331|Delta Air Lines Inc.|               DL|                                    399|
# |   2015-08|         IAD|                         608|Frontier Airlines...|               F9|                                     77|
# |   2015-09|         MIA|                        1158|           Envoy Air|              N/A|                                   null|
# |   2015-09|         MIA|                        1158|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-10|         BOS|                        1538|    Spirit Air Lines|               NK|                                      0|
# |   2015-11|         DEN|                        3335|American Airlines...|               AA|                                    327|
# |   2015-11|         DFW|                        3376|Frontier Airlines...|               F9|                                     65|
# |   2015-12|         TPA|                        1331|American Airlines...|               AA|                                    325|
# |   2015-12|         BWI|                        1537|Delta Air Lines Inc.|               DL|                                    136|
# |   2015-01|         FLL|                        1568|Frontier Airlines...|               F9|                                     60|
# |   2015-02|         DTW|                        2460|     US Airways Inc.|               US|                                    100|
# |   2015-03|         PDX|                         583|Delta Air Lines Inc.|               DL|                                    151|
# |   2015-03|         LAX|                        4571|      Virgin America|               VX|                                    470|
# |   2015-03|         BWI|                        1641|Southwest Airline...|               WN|                                   2951|
# |   2015-04|         CLT|                        1453|Frontier Airlines...|               F9|                                     29|
# |   2015-05|         IAH|                        4295|Alaska Airlines Inc.|               AS|                                     17|
# |   2015-06|         LAX|                        4910|Hawaiian Airlines...|               HA|                                     76|
# |   2015-07|         DCA|                        1561|Alaska Airlines Inc.|               AS|                                     16|
# |   2015-07|         MCO|                        2536|Alaska Airlines Inc.|               AS|                                     32|
# |   2015-09|         BOS|                        1673|      Virgin America|               VX|                                     40|
# |   2015-09|         BOS|                        1673|Southwest Airline...|               WN|                                    292|
# |   2015-10|         BWI|                         919|Delta Air Lines Inc.|               DL|                                      0|
# |   2015-10|         JFK|                        1548|Hawaiian Airlines...|               HA|                                      0|
# |   2015-11|         DTW|                        1181|Frontier Airlines...|               F9|                                     43|
# |   2015-12|         MCO|                        2387|Delta Air Lines Inc.|               DL|                                    477|
# |   2015-01|         PHL|                        1635|     US Airways Inc.|               US|                                   1763|
# |   2015-02|         PHX|                        2345|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-02|         DTW|                        2460|United Air Lines ...|               UA|                                     27|
# |   2015-02|         BOS|                        3882|      Virgin America|               VX|                                     67|
# |   2015-02|         MCO|                        2532|Southwest Airline...|               WN|                                   1270|
# |   2015-03|         DEN|                        3354|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-03|         DEN|                        3354|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-03|         LGA|                        3895|American Airlines...|               AA|                                    490|
# |   2015-04|         SEA|                        1174|Alaska Airlines Inc.|               AS|                                   1310|
# |   2015-05|         CLT|                        1209|     US Airways Inc.|               US|                                   2870|
# |   2015-09|         IAH|                        1378|Frontier Airlines...|               F9|                                     57|
# |   2015-09|         FLL|                        1103|Southwest Airline...|               WN|                                    361|
# |   2015-10|         SAN|                         683|Southwest Airline...|               WN|                                      0|
# |   2015-11|         MCO|                        1379|Frontier Airlines...|               F9|                                    287|
# |   2015-12|         PDX|                        1005|Alaska Airlines Inc.|               AS|                                    480|
# |   2015-01|         MCO|                        2272|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-01|         SAN|                        1079|Hawaiian Airlines...|               HA|                                     12|
# |   2015-01|         SFO|                        3193|United Air Lines ...|               UA|                                   1433|
# |   2015-02|         SEA|                        1299|     JetBlue Airways|               B6|                                     72|
# |   2015-02|         PDX|                         579|Hawaiian Airlines...|               HA|                                      5|
# |   2015-02|         PHL|                        1411|    Spirit Air Lines|               NK|                                     21|
# |   2015-02|         PHL|                        1411|     US Airways Inc.|               US|                                   1670|
# |   2015-03|         LGA|                        3895|      Virgin America|               VX|                                     75|
# |   2015-04|         EWR|                        1726|     US Airways Inc.|               US|                                     87|
# |   2015-05|         BOS|                        1974|American Airlines...|               AA|                                    227|
# |   2015-05|         LAX|                        3775|     US Airways Inc.|               US|                                    179|
# |   2015-05|         DCA|                        1404|Southwest Airline...|               WN|                                    412|
# |   2015-06|         LAS|                        2832|Hawaiian Airlines...|               HA|                                     35|
# |   2015-07|         SEA|                        2047|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-07|         LGA|                        3151|Delta Air Lines Inc.|               DL|                                    956|
# |   2015-07|         PHL|                        1399|United Air Lines ...|               UA|                                    121|
# |   2015-07|         LGA|                        3151|Southwest Airline...|               WN|                                    412|
# |   2015-08|         FLL|                        1594|Delta Air Lines Inc.|               DL|                                    278|
# |   2015-09|         PHX|                        1294|Alaska Airlines Inc.|               AS|                                     31|
# |   2015-11|         SEA|                        1639|     JetBlue Airways|               B6|                                     88|
# |   2015-11|         PHL|                         917|Frontier Airlines...|               F9|                                    190|
# |   2015-12|         JFK|                        2147|Delta Air Lines Inc.|               DL|                                    748|
# |   2015-01|         MSP|                        1701|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-01|         MSP|                        1701|           Envoy Air|              N/A|                                   null|
# |   2015-01|         MSP|                        1701|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-03|         SLC|                        1169|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-03|         SLC|                        1169|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-03|         CLT|                        1679|American Airlines...|               AA|                                    164|
# |   2015-03|         SFO|                        2633|     JetBlue Airways|               B6|                                    187|
# |   2015-03|         LAS|                        2287|Hawaiian Airlines...|               HA|                                     41|
# |   2015-06|         LAX|                        4910|Alaska Airlines Inc.|               AS|                                    201|
# |   2015-06|         PHL|                        1726|Delta Air Lines Inc.|               DL|                                    256|
# |   2015-06|         ORD|                        9337|    Spirit Air Lines|               NK|                                    887|
# |   2015-08|         ORD|                        5895|Frontier Airlines...|               F9|                                    316|
# |   2015-11|         JFK|                        1205|Alaska Airlines Inc.|               AS|                                      3|
# |   2015-11|         PDX|                         576|Delta Air Lines Inc.|               DL|                                    137|
# |   2015-01|         DEN|                        4211|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-01|         DEN|                        4211|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-02|         CLT|                        2017|Southwest Airline...|               WN|                                     52|
# |   2015-03|         EWR|                        2627|Delta Air Lines Inc.|               DL|                                    100|
# |   2015-04|         MIA|                        1126|United Air Lines ...|               UA|                                    111|
# |   2015-04|         ORD|                        5017|     US Airways Inc.|               US|                                    160|
# |   2015-05|         MSP|                        1666|Frontier Airlines...|               F9|                                     99|
# |   2015-05|         FLL|                        1164|Southwest Airline...|               WN|                                    321|
# |   2015-06|         DFW|                        5494|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-06|         DFW|                        5494|           Envoy Air|              N/A|                                   null|
# |   2015-06|         DFW|                        5494|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-06|         DTW|                        2423|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-06|         DTW|                        2423|           Envoy Air|              N/A|                                   null|
# |   2015-06|         DTW|                        2423|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-06|         BOS|                        2633|Delta Air Lines Inc.|               DL|                                    521|
# |   2015-06|         SEA|                        2113|      Virgin America|               VX|                                     89|
# |   2015-08|         IAH|                        2502|American Airlines...|               AA|                                    256|
# |   2015-08|         FLL|                        1594|     JetBlue Airways|               B6|                                    929|
# |   2015-09|         BOS|                        1673|American Airlines...|               AA|                                    711|
# |   2015-09|         LGA|                        1559|Southwest Airline...|               WN|                                    210|
# |   2015-12|         SAN|                        1469|American Airlines...|               AA|                                    257|
# |   2015-12|         IAH|                        2715|    Spirit Air Lines|               NK|                                    267|
# |   2015-12|         LAX|                        4708|United Air Lines ...|               UA|                                    785|
# |   2015-01|         IAD|                         950|Delta Air Lines Inc.|               DL|                                     53|
# |   2015-01|         PDX|                         664|Southwest Airline...|               WN|                                    276|
# |   2015-02|         SFO|                        3335|Hawaiian Airlines...|               HA|                                     21|
# |   2015-02|         IAH|                        2547|     US Airways Inc.|               US|                                    131|
# |   2015-04|         MSP|                        1587|Frontier Airlines...|               F9|                                     27|
# |   2015-05|         DFW|                        6066|Delta Air Lines Inc.|               DL|                                    190|
# |   2015-05|         SAN|                        1340|United Air Lines ...|               UA|                                    239|
# |   2015-06|         ORD|                        9337|Delta Air Lines Inc.|               DL|                                    428|
# |   2015-09|         ATL|                        3243|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-09|         ATL|                        3243|           Envoy Air|              N/A|                                   null|
# |   2015-09|         ATL|                        3243|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-09|         TPA|                         751|Frontier Airlines...|               F9|                                     31|
# |   2015-11|         FLL|                         993|American Airlines...|               AA|                                    167|
# |   2015-11|         DEN|                        3335|Alaska Airlines Inc.|               AS|                                     52|
# |   2015-11|         DEN|                        3335|     JetBlue Airways|               B6|                                     38|
# |   2015-11|         DEN|                        3335|Frontier Airlines...|               F9|                                    995|
# |   2015-11|         LAS|                        2025|Hawaiian Airlines...|               HA|                                     25|
# |   2015-12|         IAD|                         474|     JetBlue Airways|               B6|                                     69|
# |   2015-02|         ATL|                        5685|American Airlines...|               AA|                                    124|
# |   2015-02|         DFW|                        6194|United Air Lines ...|               UA|                                    102|
# |   2015-03|         LGA|                        3895|     JetBlue Airways|               B6|                                    344|
# |   2015-05|         IAH|                        4295|American Airlines...|               AA|                                    165|
# |   2015-06|         ATL|                        6526|American Airlines...|               AA|                                    161|
# |   2015-06|         MIA|                        1438|Delta Air Lines Inc.|               DL|                                    232|
# |   2015-08|         MDW|                        1362|Delta Air Lines Inc.|               DL|                                     48|
# |   2015-08|         MSP|                        1950|United Air Lines ...|               UA|                                    114|
# |   2015-09|         DTW|                        1198|United Air Lines ...|               UA|                                     29|
# |   2015-09|         EWR|                        1412|Southwest Airline...|               WN|                                    118|
# |   2015-11|         SAN|                        1150|American Airlines...|               AA|                                    241|
# |   2015-01|         BOS|                        2638|    Spirit Air Lines|               NK|                                     62|
# |   2015-02|         FLL|                        1926|     JetBlue Airways|               B6|                                    981|
# |   2015-03|         LGA|                        3895|Southwest Airline...|               WN|                                    454|
# |   2015-04|         IAD|                         461|ExpressJet Airlin...|              N/A|                                   null|
# ...
# |   2015-03|         DCA|                        1735|     US Airways Inc.|               US|                                    889|
# |   2015-04|         PDX|                         550|     JetBlue Airways|               B6|                                     26|
# |   2015-06|         CLT|                        1732|Frontier Airlines...|               F9|                                     34|
# |   2015-07|         ATL|                        5558|United Air Lines ...|               UA|                                    136|
# |   2015-08|         BOS|                        2519|Southwest Airline...|               WN|                                    402|
# |   2015-11|         ORD|                        4952|Delta Air Lines Inc.|               DL|                                    223|
# |   2015-11|         EWR|                        2116|United Air Lines ...|               UA|                                   1187|
# |   2015-11|         BOS|                        1426|Southwest Airline...|               WN|                                    307|
# |   2015-12|         FLL|                        2024|American Airlines...|               AA|                                    258|
# |   2015-01|         SFO|                        3193|     JetBlue Airways|               B6|                                    143|
# |   2015-01|         PHL|                        1635|Southwest Airline...|               WN|                                    294|
# |   2015-02|         LAS|                        2243|American Airlines...|               AA|                                    271|
# |   2015-03|         DTW|                        1918|    Spirit Air Lines|               NK|                                    373|
# |   2015-04|         IAH|                        3155|American Airlines...|               AA|                                    123|
# |   2015-04|         SFO|                        2635|Frontier Airlines...|               F9|                                     80|
# |   2015-04|         JFK|                        2087|      Virgin America|               VX|                                    111|
# |   2015-05|         SFO|                        3912|     US Airways Inc.|               US|                                    118|
# |   2015-06|         DCA|                        1765|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-06|         DCA|                        1765|           Envoy Air|              N/A|                                   null|
# |   2015-06|         DCA|                        1765|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-07|         MIA|                        1576|Delta Air Lines Inc.|               DL|                                    261|
# |   2015-09|         EWR|                        1412|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-09|         EWR|                        1412|           Envoy Air|              N/A|                                   null|
# |   2015-10|         DCA|                        1014|American Airlines...|               AA|                                      0|
# |   2015-11|         MCO|                        1379|American Airlines...|               AA|                                    491|
# |   2015-11|         SEA|                        1639|Delta Air Lines Inc.|               DL|                                    510|
# |   2015-12|         SLC|                        1844|American Airlines...|               AA|                                    159|
# |   2015-12|         PDX|                        1005|Frontier Airlines...|               F9|                                     21|
# |   2015-01|         EWR|                        2549|Delta Air Lines Inc.|               DL|                                    119|
# |   2015-06|         ATL|                        6526|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-06|         ATL|                        6526|           Envoy Air|              N/A|                                   null|
# |   2015-06|         ATL|                        6526|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-06|         EWR|                        3230|Southwest Airline...|               WN|                                    198|
# |   2015-07|         TPA|                        1408|American Airlines...|               AA|                                    400|
# |   2015-09|         BWI|                        1260|Alaska Airlines Inc.|               AS|                                     13|
# |   2015-09|         SEA|                        1418|Alaska Airlines Inc.|               AS|                                   1600|
# |   2015-09|         LAX|                        3034|    Spirit Air Lines|               NK|                                    227|
# |   2015-10|         LAX|                        2353|United Air Lines ...|               UA|                                      0|
# |   2015-11|         ATL|                        4144|Delta Air Lines Inc.|               DL|                                   5436|
# |   2015-11|         SFO|                        2294|United Air Lines ...|               UA|                                   1076|
# |   2015-03|         FLL|                        1782|United Air Lines ...|               UA|                                    182|
# |   2015-05|         FLL|                        1164|American Airlines...|               AA|                                     65|
# |   2015-05|         LGA|                        2344|      Virgin America|               VX|                                     74|
# |   2015-05|         MCO|                        1765|      Virgin America|               VX|                                     14|
# |   2015-06|         JFK|                        2041|      Virgin America|               VX|                                     90|
# |   2015-07|         JFK|                        2016|Delta Air Lines Inc.|               DL|                                    812|
# |   2015-09|         FLL|                        1103|American Airlines...|               AA|                                    207|
# |   2015-09|         LAS|                        1375|     JetBlue Airways|               B6|                                    141|
# |   2015-10|         LAS|                        1711|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-10|         SFO|                        2183|American Airlines...|               AA|                                      0|
# |   2015-11|         SFO|                        2294|American Airlines...|               AA|                                    387|
# |   2015-12|         JFK|                        2147|           Envoy Air|              N/A|                                   null|
# |   2015-02|         SAN|                        1233|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-02|         JFK|                        2665|American Airlines...|               AA|                                    623|
# |   2015-03|         SEA|                        1355|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-03|         LAX|                        4571|Hawaiian Airlines...|               HA|                                     44|
# |   2015-03|         PDX|                         583|      Virgin America|               VX|                                      4|
# |   2015-04|         DFW|                        5468|     JetBlue Airways|               B6|                                     32|
# |   2015-04|         FLL|                        1206|     JetBlue Airways|               B6|                                    631|
# |   2015-04|         LGA|                        2187|     US Airways Inc.|               US|                                    395|
# |   2015-05|         LAS|                        2447|Frontier Airlines...|               F9|                                    287|
# |   2015-06|         ORD|                        9337|Frontier Airlines...|               F9|                                    344|
# |   2015-06|         LGA|                        3232|United Air Lines ...|               UA|                                    351|
# |   2015-06|         LGA|                        3232|      Virgin America|               VX|                                     68|
# |   2015-08|         SEA|                        2591|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-08|         DCA|                        1389|Delta Air Lines Inc.|               DL|                                    239|
# |   2015-09|         LAS|                        1375|Delta Air Lines Inc.|               DL|                                    215|
# |   2015-09|         DEN|                        1853|United Air Lines ...|               UA|                                   1186|
# |   2015-09|         BWI|                        1260|Southwest Airline...|               WN|                                   2194|
# |   2015-09|         SAN|                         760|Southwest Airline...|               WN|                                    812|
# |   2015-10|         LAX|                        2353|Alaska Airlines Inc.|               AS|                                      0|
# |   2015-10|         TPA|                         625|     JetBlue Airways|               B6|                                      0|
# |   2015-11|         PDX|                         576|Hawaiian Airlines...|               HA|                                     12|
# |   2015-01|         CLT|                        1671|Frontier Airlines...|               F9|                                     12|
# |   2015-02|         PHX|                        2345|     US Airways Inc.|               US|                                   1767|
# |   2015-03|         LGA|                        3895|Frontier Airlines...|               F9|                                     60|
# |   2015-03|         DCA|                        1735|United Air Lines ...|               UA|                                    194|
# |   2015-04|         MCO|                        1825|American Airlines...|               AA|                                    258|
# |   2015-04|         ATL|                        4545|United Air Lines ...|               UA|                                    143|
# |   2015-04|         EWR|                        1726|United Air Lines ...|               UA|                                   1419|
# |   2015-05|         SEA|                        1389|Alaska Airlines Inc.|               AS|                                   1533|
# |   2015-05|         MSP|                        1666|Delta Air Lines Inc.|               DL|                                   1530|
# |   2015-05|         SAN|                        1340|Frontier Airlines...|               F9|                                     26|
# |   2015-05|         JFK|                        1656|Hawaiian Airlines...|               HA|                                     13|
# |   2015-05|         JFK|                        1656|United Air Lines ...|               UA|                                    111|
# |   2015-05|         SEA|                        1389|United Air Lines ...|               UA|                                    334|
# |   2015-06|         DEN|                        5174|     JetBlue Airways|               B6|                                     49|
# |   2015-06|         LAS|                        2832|    Spirit Air Lines|               NK|                                    583|
# |   2015-07|         DTW|                        1831|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-07|         DTW|                        1831|           Envoy Air|              N/A|                                   null|
# |   2015-07|         DTW|                        1831|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-07|         LAS|                        2874|Hawaiian Airlines...|               HA|                                     39|
# |   2015-09|         FLL|                        1103|    Spirit Air Lines|               NK|                                    430|
# |   2015-09|         TPA|                         751|United Air Lines ...|               UA|                                     95|
# |   2015-09|         ORD|                        4265|      Virgin America|               VX|                                     64|
# |   2015-10|         DEN|                        2260|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-11|         BWI|                        1089|     JetBlue Airways|               B6|                                     37|
# |   2015-12|         ORD|                        5219|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-12|         ORD|                        5219|           Envoy Air|              N/A|                                   null|
# |   2015-12|         ORD|                        5219|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-12|         IAH|                        2715|Frontier Airlines...|               F9|                                     83|
# |   2015-01|         BWI|                        1441|     JetBlue Airways|               B6|                                     61|
# |   2015-02|         PHL|                        1411|ExpressJet Airlin...|              N/A|                                   null|
# |   2015-02|         PHL|                        1411|SkyWest Airlines ...|              N/A|                                   null|
# |   2015-03|         SEA|                        1355|      Virgin America|               VX|                                     56|
# |   2015-04|         EWR|                        1726|      Virgin America|               VX|                                     43|
# |   2015-04|         PHL|                        1156|Southwest Airline...|               WN|                                    245|
# |   2015-05|         SLC|                         957|United Air Lines ...|               UA|                                     22|
# |   2015-06|         DCA|                        1765|      Virgin America|               VX|                                     64|
# |   2015-07|         PHL|                        1399|Frontier Airlines...|               F9|                                    137|
# |   2015-08|         TPA|                        1288|Delta Air Lines Inc.|               DL|                                    298|
# |   2015-12|         BOS|                        1913|American Airlines...|               AA|                                    665|
# |   2015-12|         SAN|                        1469|Alaska Airlines Inc.|               AS|                                    111|
# |   2015-12|         FLL|                        2024|     JetBlue Airways|               B6|                                   1063|
# |   2015-12|         SLC|                        1844|Frontier Airlines...|               F9|                                     36|
# |   2015-12|         IAD|                         474|United Air Lines ...|               UA|                                    435|
# |   2015-04|         TPA|                         971|Delta Air Lines Inc.|               DL|                                    253|
# |   2015-04|         IAD|                         461|      Virgin America|               VX|                                     39|
# +----------+------------+----------------------------+--------------------+-----------------+---------------------------------------+
# only showing top 1000 rows

# %%
df_res.createOrReplaceTempView('df_res')

# %%
df_lve = spark.sql('''
SELECT 
    airline_name
FROM airlines_json
    LATERAL VIEW EXPLODE(split(`Statistics.Carriers.Names`, ',')) AS airline_name
WHERE `Statistics.Minutes Delayed.Carrier` = 61606
''')
# df1.count()
df_lve.show(400)
# Out:
# +--------------------+
# |        airline_name|
# +--------------------+
# |American Airlines...|
# |     JetBlue Airways|
# |Continental Air L...|
# |Delta Air Lines Inc.|
# |Atlantic Southeas...|
# |AirTran Airways C...|
# |America West Airl...|
# |Northwest Airline...|
# |ExpressJet Airlin...|
# |United Air Lines ...|
# |     US Airways Inc.|
# +--------------------+

# %% [markdown]
# # 1.1.2. Compare query results with corresponding golden dataset using Spark SQL. Do not use EXCEPT clause

# %%
df_parquet = spark.read.parquet('golden_dataset/query2')
df_parquet.createOrReplaceTempView('df_parquet')

# %%
# df_parquet.show()
df_parquet.printSchema()
# Out:
# root
#  |-- year_month: string (nullable = true)
#  |-- airport_code: string (nullable = true)
#  |-- number_of_delays_for_airport: long (nullable = true)
#  |-- airline_name: string (nullable = true)
#  |-- airline_iata_code: string (nullable = true)
#  |-- number_of_delays_for_airline_in_airport: long (nullable = true)

# %%
df_res.printSchema()
# Out:
# root
#  |-- year_month: string (nullable = true)
#  |-- airport_code: string (nullable = true)
#  |-- number_of_delays_for_airport: long (nullable = true)
#  |-- airline_name: string (nullable = true)
#  |-- airline_iata_code: string (nullable = false)
#  |-- number_of_delays_for_airline_in_airport: long (nullable = true)

# %%
df_diff = spark.sql('''
SELECT *
FROM df_parquet MINUS ALL
    SELECT * FROM df_res
UNION ALL
SELECT *
FROM df_res MINUS ALL
    SELECT * FROM df_parquet
''')
df_diff.createOrReplaceTempView('df_diff')

# %%
df_diff.count()
# Out:
# 0

# %% [markdown]
# # 1.1.3. Save difference between datasets (if any) to both Excel and Parquet files

# %%
df_diff.toPandas().to_csv('df_diff_1.csv', header=True)
df_diff.write.parquet("df_diff_1.parquet", 'overwrite')

import pandas as pd 
import numpy as np 

# Reading the csv file 
df_csv = pd.read_csv('df_diff_1.csv') 
  
# saving xlsx file 
xlsx_writer = pd.ExcelWriter('df_diff_1.xlsx') 
df_csv.to_excel(xlsx_writer, index = False) 
  
xlsx_writer.save()

# %%
df_diff.show()
# Out:
# +----------+------------+----------------------------+------------+-----------------+---------------------------------------+
# |year_month|airport_code|number_of_delays_for_airport|airline_name|airline_iata_code|number_of_delays_for_airline_in_airport|
# +----------+------------+----------------------------+------------+-----------------+---------------------------------------+
# +----------+------------+----------------------------+------------+-----------------+---------------------------------------+

# %% [markdown]
# # 1.1.4. Create test report consisting of:
# 	- Spark SQL query
# 	- datasets comparison query
# 	- difference between datasets' rows in Excel format
# 	- difference between datasets' rows in Parquet format

# %%
df_diff.describe().show()
# Out:
# +-------+----------+------------+----------------------------+------------+-----------------+---------------------------------------+
# |summary|year_month|airport_code|number_of_delays_for_airport|airline_name|airline_iata_code|number_of_delays_for_airline_in_airport|
# +-------+----------+------------+----------------------------+------------+-----------------+---------------------------------------+
# |  count|         0|           0|                           0|           0|                0|                                      0|
# |   mean|      null|        null|                        null|        null|             null|                                   null|
# | stddev|      null|        null|                        null|        null|             null|                                   null|
# |    min|      null|        null|                        null|        null|             null|                                   null|
# |    max|      null|        null|                        null|        null|             null|                                   null|
# +-------+----------+------------+----------------------------+------------+-----------------+---------------------------------------+

# %%
df_diff.summary().show()
# Out:
# +-------+----------+------------+----------------------------+------------+-----------------+---------------------------------------+
# |summary|year_month|airport_code|number_of_delays_for_airport|airline_name|airline_iata_code|number_of_delays_for_airline_in_airport|
# +-------+----------+------------+----------------------------+------------+-----------------+---------------------------------------+
# |  count|         0|           0|                           0|           0|                0|                                      0|
# |   mean|      null|        null|                        null|        null|             null|                                   null|
# | stddev|      null|        null|                        null|        null|             null|                                   null|
# |    min|      null|        null|                        null|        null|             null|                                   null|
# |    25%|      null|        null|                        null|        null|             null|                                   null|
# |    50%|      null|        null|                        null|        null|             null|                                   null|
# |    75%|      null|        null|                        null|        null|             null|                                   null|
# |    max|      null|        null|                        null|        null|             null|                                   null|
# +-------+----------+------------+----------------------------+------------+-----------------+---------------------------------------+
